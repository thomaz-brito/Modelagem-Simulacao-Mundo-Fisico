# %% [markdown]
# # Insper - Modelagem e Simulação do Mundo Físico
#
# ## Atividade - ODEINT em sistemas (Parte 1)

# %% [markdown]
# ----
#
# ## Introdução
#
# Como você já deve saber, os códigos compilados no Jupyter Notebook rodam um na sequência do outro. Se você declara uma variável no começo, pode utilizar essa mesma variável mais adiante.
#
# Dessa forma, vamos já importar todas as bibliotecas que serão utilizadas nessa atividade, para não precisarmos importar novamente. Para tal, basta rodar o código abaixo antes de ir para o próximo item.

# %%
# Importa bibliotecas necessárias
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ----
#
# ## Item 1 - Relembrando ODEINT
#
# Inicialmente, vamos relembrar como usar `odeint` no caso de apenas uma equação diferencial, tal qual fizemos na aula passada.

# %% [markdown]
# ### a)
#
# Para isso, resolva a seguinte equação:
#
# $$\dfrac{dy}{dt}=\frac{2y}{t+1}$$
# $$y(0) = -1$$
#
# Considere uma lista de $0$ a $5$ com $\Delta t = 0,001$.
#
# Após resolvê-la, plote o gráfico de $y(t)$ por $t$.

# %%
# SEU CÓDIGO DO ITEM 1A

# %% [markdown]
# ----
#
# ## Item 2 - ODEINT em sistema de equações diferenciais
#
# Agora, vamos aplicar `odeint` na resolução do seguinte sistema de equações diferenciais:
#
# $$\frac{dL}{dt}= L\cdot\biggl(\frac{A}{20}-1\biggr)$$
#
# $$\frac{dA}{dt}= A\cdot\biggl(1- \frac{L}{10}\biggr)$$
#
# Os valores iniciais $L(0)$ e $A(0)$ devem ser:
#
# - $L(0)=$ 20
# - $A(0)=$ 35

# %% [markdown]
# ### a) Função que calcula as derivadas
#
# Implemente uma função denominada `modelo` que recebe uma lista com os estoques $x = [L \quad A]$ e o instante de tempo $t$ e retorna uma lista com as taxas de variação dos estoques $\frac{dx}{dt} = [\frac{dL}{dt} \quad \frac{dA}{dt}]$. Mesmo que sua função não utilize a variável $t$, ela é obrigatória para o correto funcionamento da função `odeint`.

# %%
# SEU CÓDIGO DO ITEM 2A

# %% [markdown]
# ### b) Aplicação de `odeint`
# Agora que você implementou a função `modelo`, utilize a função `odeint` para resolver o sistema, obtendo as listas com os valores de $L(t)$ e $A(t)$.
#
# Para isso, utilize uma lista de tempo de 0 a 20 com $\Delta t=10^{-4}$.

# %%
# SEU CÓDIGO DO ITEM 2B

# %% [markdown]
# ### c) Gráfico
#
# Após resolver as equações, plote **em uma mesma figura** os gráficos de $L(t)$ por $t$ e $A(t)$ por $t$.
#
# Não se esqueça de que a estrutura de dados da solução do `odeint` é uma matriz (um "array") em que a primeira coluna tem os valores de $L(t)$ e, a segunda, os valores de $A(t)$. Por isso, precisamos usar um caractere de separação (um "split"). Isso se faz com o código `[:,0]` para obter os dados da primeira coluna e `[:,1]` para obter os da segunda coluna.

# %%
# SEU CÓDIGO DO ITEM 2C

# %% [markdown]
# ---
#
# ## Item 3 - Relembrando o método de Euler (agora em sistema de sistema de equações diferenciais)
#
# Agora que você usou a função `odeint`, vamos implementar uma solução numérica para o mesmo modelo usando o método de Euler. Isso será feito de duas formas:
#
# - a) Primeira forma: digitando as expressões das derivadas diretamente no loop
# - b) Segunda forma: usando a função que calcula as derivadas
#
# A primeira forma é análoga ao que fizemos na aula passada. Caso não se lembre, **consulte seus arquivos da aula passada antes de prosseguir**.

# %% [markdown]
# ### a) Primeira forma: digitando as expressões das derivadas diretamente no loop
#
# Usando a mesma lista de tempo do **item 2**, comece gerando as listas que serão preenchidas com os valores de $L(t)$ e $A(t)$. Em seguida, resolva-as pelo método de Euler da mesma forma que você fez na aula passada, ou seja, digitando as expressões de $\frac{dL}{dt}$ e $\frac{dA}{dt}$ diretamente no loop.
#
# Após a resolução, plote os gráficos e veja se você obteve o mesmo resultado do item anterior.

# %%
# SEU CÓDIGO DO ITEM 3A

# %% [markdown]
# ### b) Segunda forma: usando a função que calcula as derivadas
#
# Copie e cole seu código do item anterior e adapte-o para que o valor das derivadas $\frac{dL}{dt}$ e $\frac{dA}{dt}$ seja fornecido pela função que você definiu no **item 2a**, em vez de fornecer suas expressões diretamente no loop.
#
# Após a resolução, plote os gráficos e veja se você obteve o mesmo resultado dos itens anteriores.

# %%
# SEU CÓDIGO DO ITEM 3B
